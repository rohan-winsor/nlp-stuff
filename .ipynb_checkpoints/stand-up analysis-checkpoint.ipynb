# %%
import requests 
from bs4 import BeautifulSoup
import pickle 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import text
import pandas as pd 
import re
import numpy as np
import string 
import matplotlib.pyplot as plt
from tqdm import tqdm
from collections import Counter

# %%
# Data
# URLs of transcripts in scope
urls = ['http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/',
        'http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/',
        'http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/',
        'http://scrapsfromtheloft.com/2017/08/07/bo-burnham-2013-full-transcript/',
        'http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/',
        'http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/',
        'http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/',
        'http://scrapsfromtheloft.com/2017/10/21/hasan-minhaj-homecoming-king-2017-full-transcript/',
        'http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/',
        'http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/',
        'http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/',
        'http://scrapsfromtheloft.com/2017/08/19/joe-rogan-triggered-2016-full-transcript/']

# Comedian names
comedians = ['louis', 'dave', 'ricky', 'bo', 'bill', 'jim', 'john', 'hasan', 'ali', 'anthony', 'mike', 'joe']

# %%
def url_to_transcript(url):
    '''Returns transcript data specifically from scrapsfromtheloft.com.'''
    page = requests.get(url).text
    soup = BeautifulSoup(page, "html")
    text = [p.text for p in soup.find(class_="post-content").find_all('p')]
    print(url)
    return text

# %%
data = [url_to_transcript(i) for i in urls]
# Out:
# http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/
# http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/
# http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/
# http://scrapsfromtheloft.com/2017/08/07/bo-burnham-2013-full-transcript/
# http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/
# http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/
# http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/
# http://scrapsfromtheloft.com/2017/10/21/hasan-minhaj-homecoming-king-2017-full-transcript/
# http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/
# http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/
# http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/
# http://scrapsfromtheloft.com/2017/08/19/joe-rogan-triggered-2016-full-transcript/

# %%
print(data[0][2])
# Out:
# “My Daughter Likes Fish”
# You ever flush a pet down the toilet? I had to flush my daughter’s fish down the toilet. I came home, the fish was dead. She wasn’t home from school yet, so I just flushed the fish, And that’s a weird moment, too, ’cause fish live in water. So you put it in the toilet, floats to the bottom, Like, “yeah, he’s dead,” And then you flush, and it looks like he goes, “wait a second! Aw, shit! “I was taking a nap! Jesus! “you gotta be in constant motion To get any respect in this house.” And then my daughter comes home. “why did he die, da–” Come on. What am I gonna say? Why did he die? Because who gives a shit? That’s the reason. That’s the actual reason, is because didn’t matter That he was alive. That’s why he’s dead. He didn’t know his name, and he didn’t love you back. These are the facts about that fish’s life. My daughter likes fish. We took her to the aquarium. I took both my kids to the aquarium in boston, And we were looking at this seal, or sea lion. I don’t know which one. I don’t care. I don’t think they need to be separate things. I really don’t. They don’t care, and we don’t care. There’s, like, three scientists Who give a shit what we call all those things. The scientists could go on TV tomorrow And say, “ok, everybody. “from now on, seals and sea lions and walruses, And–you know what?–Penguins are all seals now,” And we would all be like, “yeah, all right. Fine. Yes. Whatever, man.” Anyway, so we’re looking at this seal/sea lion thing, And he’s looking back at us through the plexiglas, And he’s going– They’re really disgusting in person. Most animals are when you really see them. You ever go to a farm? You think you’re gonna see little, white sheep Going, “baa,” but they’re all fat and shit-colored, And they’re like– Jesus. That thing is awful. Anyway, seals don’t go– They go– My daughter’s like, “what is he saying?” I don’t know! “I’m a slave! Kill me!”

# %%
df = pd.DataFrame()
df['Comedian'] = comedians
df['Transcripts'] = data
df.to_csv("Transcripts.csv",index=False)

# %%
df
# Out:
#    Comedian                                        Transcripts
# 0     louis  [Intro\nFade the music out. Let’s roll. Hold t...
# 1      dave  [This is Dave. He tells dirty jokes for a livi...
# 2     ricky  [Hello. Hello! How you doing? Great. Thank you...
# 3        bo  [Bo What? Old MacDonald had a farm E I E I O A...
# 4      bill  [[cheers and applause] All right, thank you! T...
# 5       jim  [[Car horn honks] [Audience cheering] [Announc...
# 6      john  [All right, Petunia. Wish me luck out there. Y...
# 7     hasan  [[theme music: orchestral hip-hop] [crowd roar...
# 8       ali  [Ladies and gentlemen, please welcome to the s...
# 9   anthony  [Thank you. Thank you. Thank you, San Francisc...
# 10     mike  [Wow. Hey, thank you. Thanks. Thank you, guys....
# 11      joe  [[rock music playing] [audience cheering] [ann...

# %%
df['Transcripts'] = df['Transcripts'].apply(lambda x : ' '.join(x))

# %%
df.head()
# Out:
#   Comedian                                        Transcripts
# 0    louis  Intro\nFade the music out. Let’s roll. Hold th...
# 1     dave  This is Dave. He tells dirty jokes for a livin...
# 2    ricky  Hello. Hello! How you doing? Great. Thank you....
# 3       bo  Bo What? Old MacDonald had a farm E I E I O An...
# 4     bill  [cheers and applause] All right, thank you! Th...

# %%
df[df['Comedian'] == 'ali']['Transcripts']
# Out:
# 8    Ladies and gentlemen, please welcome to the st...
# Name: Transcripts, dtype: object

# %%
# Clean Data
df['Transcripts'] = df.Transcripts.apply(lambda x: re.sub(r'\[.*?\]|[%s]|\w*\d\w*|\n|[‘’“”…]'\
                                                                  % re.escape(string.punctuation), '',x).lower())

# %%
df.set_index('Comedian',inplace=True)
df.head()
# Out:
#                                                 Transcripts
# Comedian
# louis     introfade the music out lets roll hold there l...
# dave      this is dave he tells dirty jokes for a living...
# ricky     hello hello how you doing great thank you wow ...
# bo        bo what old macdonald had a farm e i e i o and...
# bill       all right thank you thank you very much thank...

# %%
cv = CountVectorizer(stop_words='english')

# %%
data_cv = cv.fit_transform(df['Transcripts'])

# %%
data2 = pd.DataFrame(data_cv.toarray(),columns=cv.get_feature_names())
data2.index = df.index

# %%
# Document word matrix format
data2
# Out:
#           aaaaah  aaaaahhhhhhh  aaaaauuugghhhhhh  aaaahhhhh  aaah  aah  abc  \
# Comedian
# louis          0             0                 0          0     0    3    0
# dave           0             0                 0          0     1    0    0
# ricky          0             0                 0          0     0    0    0
# bo             0             1                 1          1     0    0    0
# bill           1             0                 0          0     0    0    0
# jim            0             0                 0          0     0    0    0
# john           0             0                 0          0     0    0    0
# hasan          0             0                 0          0     0    0    0
# ali            0             0                 0          0     0    0    1
# anthony        0             0                 0          0     0    0    0
# mike           0             0                 0          0     0    0    0
# joe            0             0                 0          0     0    0    0
#
#           abcs  ability  abject  ...  zee  zen  zeppelin  zero  zillion  \
# Comedian                         ...
# louis        0        0       0  ...    0    0         0     2        0
# dave         0        0       0  ...    0    0         0     0        0
# ricky        0        1       1  ...    0    0         0     0        0
# bo           0        1       0  ...    0    0         0     1        0
# bill         1        0       0  ...    0    0         0     1        1
# jim          0        0       0  ...    0    0         0     0        0
# john         0        0       0  ...    0    0         0     0        0
# hasan        0        0       0  ...    2    1         0     1        0
# ali          0        0       0  ...    0    0         0     0        0
# anthony      0        0       0  ...    0    0         0     0        0
# mike         0        0       0  ...    0    0         2     1        0
# joe          0        0       0  ...    0    0         0     0        0
#
#           zombie  zombies  zoning  zoo  éclair
# Comedian
# louis          0        0       0    0       0
# dave           0        0       0    0       0
# ricky          0        0       0    1       0
# bo             0        0       0    0       0
# bill           1        1       1    0       0
# jim            0        0       0    0       0
# john           0        0       0    0       1
# hasan          0        0       0    0       0
# ali            1        0       0    0       0
# anthony        0        0       0    0       0
# mike           0        0       0    0       0
# joe            0        0       0    0       0
#
# [12 rows x 7486 columns]

# %%
with open('cv.pkl','wb') as f:
    pickle.dump(cv,f)

# %% [markdown]
# # EDA
# ##### Exploratory Data Analysis
#  - Top words
#  - Lexicon
#  - Swearing

# %%
dt = data2.transpose()
dt
# Out:
# Comedian          louis  dave  ricky  bo  bill  jim  john  hasan  ali  \
# aaaaah                0     0      0   0     1    0     0      0    0
# aaaaahhhhhhh          0     0      0   1     0    0     0      0    0
# aaaaauuugghhhhhh      0     0      0   1     0    0     0      0    0
# aaaahhhhh             0     0      0   1     0    0     0      0    0
# aaah                  0     1      0   0     0    0     0      0    0
# ...                 ...   ...    ...  ..   ...  ...   ...    ...  ...
# zombie                0     0      0   0     1    0     0      0    1
# zombies               0     0      0   0     1    0     0      0    0
# zoning                0     0      0   0     1    0     0      0    0
# zoo                   0     0      1   0     0    0     0      0    0
# éclair                0     0      0   0     0    0     1      0    0
#
# Comedian          anthony  mike  joe
# aaaaah                  0     0    0
# aaaaahhhhhhh            0     0    0
# aaaaauuugghhhhhh        0     0    0
# aaaahhhhh               0     0    0
# aaah                    0     0    0
# ...                   ...   ...  ...
# zombie                  0     0    0
# zombies                 0     0    0
# zoning                  0     0    0
# zoo                     0     0    0
# éclair                  0     0    0
#
# [7486 rows x 12 columns]

# %%
word_frequency = {}
for i in tqdm(dt.columns):
    word_count = dt[i].sort_values(ascending=False).head(30)
    word_frequency[i] = list(zip(word_count.index, word_count.values))
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 374.65it/s]

# %%
word_frequency['louis']
# Out:
# [('like', 110),
#  ('just', 97),
#  ('know', 70),
#  ('dont', 53),
#  ('thats', 51),
#  ('im', 50),
#  ('youre', 50),
#  ('life', 41),
#  ('people', 40),
#  ('thing', 31),
#  ('hes', 29),
#  ('gonna', 29),
#  ('theres', 28),
#  ('cause', 28),
#  ('shit', 25),
#  ('time', 22),
#  ('tit', 22),
#  ('good', 22),
#  ('theyre', 21),
#  ('think', 21),
#  ('right', 21),
#  ('really', 20),
#  ('course', 19),
#  ('kids', 18),
#  ('guy', 18),
#  ('murder', 18),
#  ('ok', 17),
#  ('old', 15),
#  ('didnt', 15),
#  ('mean', 15)]

# %%
word_count = pd.DataFrame(list(word_frequency.items()))

# %%
word_count
# Out:
#           0                                                  1
# 0     louis  [(like, 110), (just, 97), (know, 70), (dont, 5...
# 1      dave  [(like, 103), (know, 79), (said, 63), (just, 6...
# 2     ricky  [(right, 110), (like, 80), (im, 66), (just, 66...
# 3        bo  [(know, 50), (like, 44), (love, 37), (im, 37),...
# 4      bill  [(like, 200), (just, 149), (right, 131), (im, ...
# 5       jim  [(like, 108), (im, 101), (dont, 90), (right, 8...
# 6      john  [(like, 190), (know, 66), (just, 53), (dont, 5...
# 7     hasan  [(like, 220), (im, 136), (know, 70), (dont, 64...
# 8       ali  [(like, 126), (im, 74), (know, 65), (just, 64)...
# 9   anthony  [(im, 60), (like, 50), (know, 39), (dont, 38),...
# 10     mike  [(like, 234), (im, 142), (know, 105), (said, 8...
# 11      joe  [(like, 143), (people, 100), (just, 87), (dont...

# %%
words = []
for comedian in data2.index:
    top = [word for (word,_) in word_frequency[comedian]]
    for i in top:
        words.append(i)
print(len(words))
# Out:
# 360

# %%
new_stop = [words for (words,count) in Counter(words).most_common() if count > 6]
new_stop
# Out:
# ['like',
#  'just',
#  'know',
#  'dont',
#  'thats',
#  'im',
#  'people',
#  'right',
#  'youre',
#  'got',
#  'time',
#  'gonna',
#  'think',
#  'said',
#  'yeah']

# %%
# things to remove 
stopper = text.ENGLISH_STOP_WORDS.union(new_stop)
cv = CountVectorizer(stop_words=stopper)
dwmf = cv.fit_transform(df['Transcripts'])
df_dwm = pd.DataFrame(dwmf.toarray(), columns=cv.get_feature_names())
df_dwm.index = df.index

# %%
df_dwmt = df_dwm.transpose()
df_dwmt
# Out:
# Comedian          louis  dave  ricky  bo  bill  jim  john  hasan  ali  \
# aaaaah                0     0      0   0     1    0     0      0    0
# aaaaahhhhhhh          0     0      0   1     0    0     0      0    0
# aaaaauuugghhhhhh      0     0      0   1     0    0     0      0    0
# aaaahhhhh             0     0      0   1     0    0     0      0    0
# aaah                  0     1      0   0     0    0     0      0    0
# ...                 ...   ...    ...  ..   ...  ...   ...    ...  ...
# zombie                0     0      0   0     1    0     0      0    1
# zombies               0     0      0   0     1    0     0      0    0
# zoning                0     0      0   0     1    0     0      0    0
# zoo                   0     0      1   0     0    0     0      0    0
# éclair                0     0      0   0     0    0     1      0    0
#
# Comedian          anthony  mike  joe
# aaaaah                  0     0    0
# aaaaahhhhhhh            0     0    0
# aaaaauuugghhhhhh        0     0    0
# aaaahhhhh               0     0    0
# aaah                    0     0    0
# ...                   ...   ...  ...
# zombie                  0     0    0
# zombies                 0     0    0
# zoning                  0     0    0
# zoo                     0     0    0
# éclair                  0     0    0
#
# [7471 rows x 12 columns]

# %%
nword_frequency = {}
for i in tqdm(df_dwmt.columns):
    word_count = df_dwmt[i].sort_values(ascending=False).head(20)
    nword_frequency[i] = list(zip(word_count.index, word_count.values))
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 475.06it/s]

# %%
nword_frequency
# Out:
# {'louis': [('life', 41),
#   ('thing', 31),
#   ('hes', 29),
#   ('cause', 28),
#   ('theres', 28),
#   ('shit', 25),
#   ('good', 22),
#   ('tit', 22),
#   ('theyre', 21),
#   ('really', 20),
#   ('course', 19),
#   ('kids', 18),
#   ('guy', 18),
#   ('murder', 18),
#   ('ok', 17),
#   ('didnt', 15),
#   ('fuck', 15),
#   ('mean', 15),
#   ('old', 15),
#   ('way', 14)],
#  'dave': [('shit', 45),
#   ('didnt', 39),
#   ('ahah', 38),
#   ('fuck', 33),
#   ('fucking', 32),
#   ('black', 31),
#   ('man', 30),
#   ('good', 27),
#   ('lot', 20),
#   ('nigga', 20),
#   ('gay', 20),
#   ('hes', 19),
#   ('did', 19),
#   ('oh', 18),
#   ('oj', 18),
#   ('come', 17),
#   ('guys', 16),
#   ('kevin', 16),
#   ('room', 15),
#   ('whats', 15)],
#  'ricky': [('fucking', 47),
#   ('say', 43),
#   ('went', 40),
#   ('id', 39),
#   ('didnt', 33),
#   ('little', 32),
#   ('joke', 31),
#   ('hes', 29),
#   ('theyre', 29),
#   ('ive', 28),
#   ('going', 26),
#   ('thing', 26),
#   ('years', 24),
#   ('day', 23),
#   ('theres', 22),
#   ('saying', 22),
#   ('big', 21),
#   ('hed', 21),
#   ('ill', 21),
#   ('oh', 19)],
#  'bo': [('love', 37),
#   ('bo', 35),
#   ('stuff', 33),
#   ('repeat', 31),
#   ('want', 25),
#   ('cos', 23),
#   ('fucking', 22),
#   ('eye', 22),
#   ('prolonged', 21),
#   ('um', 21),
#   ('contact', 21),
#   ('good', 17),
#   ('sluts', 17),
#   ('man', 17),
#   ('little', 17),
#   ('oh', 15),
#   ('fuck', 15),
#   ('sad', 15),
#   ('brain', 15),
#   ('story', 14)],
#  'bill': [('fucking', 70),
#   ('shit', 63),
#   ('dude', 40),
#   ('fuck', 36),
#   ('want', 36),
#   ('hes', 31),
#   ('did', 31),
#   ('guy', 30),
#   ('didnt', 29),
#   ('make', 28),
#   ('come', 27),
#   ('going', 26),
#   ('thing', 26),
#   ('theyre', 25),
#   ('let', 24),
#   ('theres', 24),
#   ('little', 23),
#   ('doing', 23),
#   ('guys', 22),
#   ('hey', 21)],
#  'jim': [('fucking', 78),
#   ('went', 63),
#   ('day', 40),
#   ('oh', 40),
#   ('going', 39),
#   ('fuck', 37),
#   ('thing', 34),
#   ('goes', 34),
#   ('guns', 30),
#   ('theyre', 29),
#   ('good', 28),
#   ('ive', 27),
#   ('women', 26),
#   ('cause', 26),
#   ('theres', 26),
#   ('want', 25),
#   ('really', 23),
#   ('hes', 23),
#   ('guy', 21),
#   ('come', 21)],
#  'john': [('clinton', 34),
#   ('little', 26),
#   ('hey', 25),
#   ('say', 22),
#   ('cause', 22),
#   ('mom', 22),
#   ('oh', 21),
#   ('old', 21),
#   ('day', 21),
#   ('way', 21),
#   ('cow', 20),
#   ('wife', 18),
#   ('went', 18),
#   ('really', 18),
#   ('real', 17),
#   ('dad', 17),
#   ('walked', 16),
#   ('shes', 16),
#   ('house', 16),
#   ('didnt', 16)],
#  'hasan': [('dad', 59),
#   ('going', 41),
#   ('want', 38),
#   ('love', 34),
#   ('shes', 32),
#   ('hasan', 31),
#   ('say', 30),
#   ('mom', 25),
#   ('life', 25),
#   ('oh', 24),
#   ('hey', 24),
#   ('did', 22),
#   ('look', 22),
#   ('brown', 21),
#   ('guys', 20),
#   ('white', 20),
#   ('parents', 20),
#   ('whats', 19),
#   ('school', 19),
#   ('girl', 19)],
#  'ali': [('shit', 34),
#   ('ok', 26),
#   ('lot', 24),
#   ('oh', 21),
#   ('gotta', 21),
#   ('wanna', 21),
#   ('husband', 20),
#   ('cause', 18),
#   ('day', 17),
#   ('women', 17),
#   ('pregnant', 15),
#   ('hes', 14),
#   ('god', 14),
#   ('need', 14),
#   ('tell', 13),
#   ('dude', 12),
#   ('really', 12),
#   ('work', 12),
#   ('theyre', 12),
#   ('fuck', 11)],
#  'anthony': [('joke', 34),
#   ('anthony', 27),
#   ('day', 26),
#   ('say', 26),
#   ('guys', 23),
#   ('tell', 19),
#   ('grandma', 18),
#   ('thing', 17),
#   ('school', 16),
#   ('good', 16),
#   ('did', 16),
#   ('jokes', 16),
#   ('baby', 15),
#   ('ive', 15),
#   ('okay', 15),
#   ('mad', 14),
#   ('didnt', 14),
#   ('hate', 14),
#   ('family', 14),
#   ('shark', 14)],
#  'mike': [('says', 46),
#   ('cause', 35),
#   ('jenny', 33),
#   ('goes', 32),
#   ('really', 30),
#   ('id', 30),
#   ('point', 28),
#   ('mean', 28),
#   ('kind', 23),
#   ('uh', 22),
#   ('say', 21),
#   ('feel', 20),
#   ('want', 19),
#   ('going', 19),
#   ('didnt', 19),
#   ('way', 18),
#   ('oh', 18),
#   ('tell', 18),
#   ('car', 17),
#   ('good', 17)],
#  'joe': [('fucking', 69),
#   ('fuck', 66),
#   ('theyre', 49),
#   ('shit', 40),
#   ('theres', 34),
#   ('man', 30),
#   ('house', 27),
#   ('oh', 25),
#   ('kids', 25),
#   ('cause', 24),
#   ('white', 24),
#   ('say', 23),
#   ('real', 22),
#   ('life', 21),
#   ('really', 20),
#   ('make', 20),
#   ('dude', 20),
#   ('gotta', 20),
#   ('going', 20),
#   ('girl', 19)]}

# %%
i = 'dave'
D = dict(nword_frequency[i])
plt.title(i)
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
plt.show()

# %%
total_words = []
for i in df_dwmt.columns:
    tot = sum(df_dwmt[i])
    total_words.append(tot)
unique = []
for i in df_dwmt.columns:
    tot = df_dwmt[i].to_numpy().nonzero()[0].size
    unique.append(tot)

# %%
df['total_words'] = total_words
df['unique'] = unique
df
# Out:
#                                                 Transcripts  total_words  \
# Comedian
# louis     introfade the music out lets roll hold there l...         2693
# dave      this is dave he tells dirty jokes for a living...         3474
# ricky     hello hello how you doing great thank you wow ...         4238
# bo        bo what old macdonald had a farm e i e i o and...         2774
# bill       all right thank you thank you very much thank...         4325
# jim          ladies and gentlemen please welcome to the ...         3983
# john      all right petunia wish me luck out there you w...         3363
# hasan       whats up davis whats up im home i had to bri...         4003
# ali       ladies and gentlemen please welcome to the sta...         2705
# anthony   thank you thank you thank you san francisco th...         2473
# mike      wow hey thank you thanks thank you guys hey se...         3732
# joe          ladies and gentlemen welcome joe rogan  wha...         3756
#
#           unique
# Comedian
# louis       1084
# dave        1390
# ricky       1618
# bo          1258
# bill        1620
# jim         1298
# john        1377
# hasan       1547
# ali         1329
# anthony      969
# mike        1481
# joe         1422

# %% [markdown]
# # Sentiment Analysis
